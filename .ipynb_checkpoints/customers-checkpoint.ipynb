# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import mysql.connector

# %% [markdown]
# # CUSTOMERS

# %%
customers_df= pd.read_csv("C:\\Users\\admin\\python\\Customers.csv",encoding ="ISO-8859-1")

# %%
customers_df.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia    7/3/1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
#data_conversion
customers_df["Birthday"] = pd.to_datetime(customers_df['Birthday'], format="%m/%d/%Y", errors='coerce').dt.date

# %%
customers_df.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  1939-07-03
# 1  Western Australia     6522  Australia  Australia  1979-09-27
# 2           Victoria     3380  Australia  Australia  1947-05-26
# 3    South Australia     5223  Australia  Australia  1957-09-17
# 4           Victoria     3698  Australia  Australia  1965-11-19

# %%
#checking the missing values
customers_df.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
#droping missing values
#customers_df.dropna(inplace=True)

# %%
#customers_df.isnull().sum()

# %%
#dropping columns

#customers_df.drop(["State Code","Zip Code"],axis=1,inplace=True)

# %%
customers_df['State Code']=customers_df['State Code'].fillna('NPO')

# %%
customers_df.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  1939-07-03
# 1  Western Australia     6522  Australia  Australia  1979-09-27
# 2           Victoria     3380  Australia  Australia  1947-05-26
# 3    South Australia     5223  Australia  Australia  1957-09-17
# 4           Victoria     3698  Australia  Australia  1965-11-19

# %%
#creating column age using datetime

today = datetime.today()
customers_df["Age"] =customers_df["Birthday"].apply(
    lambda x:today.year - x.year-((today.month,today.day)<(x.month,x.day)))

# %%
customers_df.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday  Age
# 0    South Australia     5523  Australia  Australia  1939-07-03   85
# 1  Western Australia     6522  Australia  Australia  1979-09-27   44
# 2           Victoria     3380  Australia  Australia  1947-05-26   77
# 3    South Australia     5223  Australia  Australia  1957-09-17   66
# 4           Victoria     3698  Australia  Australia  1965-11-19   58

# %% [markdown]
# # visualization

# %%
#customers_df["Name"].count()
# Out:
# 15256

# %%
#df=customers_df.groupby("CustomerKey")["Country"].count().reset_index()

# %%
#df.columns=["CustomerKey","Country"]

# %%
# count=customers_df.groupby(["City","State"])["Country"].sum().reset_index()

# %%
# sns.set_style("darkgrid")
# plt.figure(figsize=(20,5))
# sns.barplot(data=count,x="City",y="Country",hue="State")
# plt.title("bar chart")
# plt.show()

# %%
customers_df.describe()
# Out:
#         CustomerKey           Age
# count  1.526600e+04  15266.000000
# mean   1.060508e+06     55.457356
# std    6.127097e+05     19.321072
# min    3.010000e+02     22.000000
# 25%    5.140335e+05     39.000000
# 50%    1.079244e+06     56.000000
# 75%    1.593980e+06     72.000000
# max    2.099937e+06     89.000000

# %%
#df= customers_df["CustomerKey"].count()

# %%
#df_1=customers_df["Country"]

# %%
#plt.pie(df,df_1,autopct="%1.2f%%")

# %%
#grouping
data=customers_df[["CustomerKey","Country"]].groupby(["Country"]).count()

# %%
data
# Out:
#                 CustomerKey
# Country
# Australia              1420
# Canada                 1553
# France                  670
# Germany                1473
# Italy                   645
# Netherlands             733
# United Kingdom         1944
# United States          6828

# %%
plt.figure(figsize=(17,5))
sns.set_style("darkgrid")
sns.barplot(data=data,x="Country",y="CustomerKey",palette='summer')
plt.ylabel("Customers")
plt.title("Comparison by customer count")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4312\2662359664.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x="Country",y="CustomerKey",palette='summer')

# %%
#adding new column to categorize age group

# %%
customers_df.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday  Age
# 0    South Australia     5523  Australia  Australia  1939-07-03   85
# 1  Western Australia     6522  Australia  Australia  1979-09-27   44
# 2           Victoria     3380  Australia  Australia  1947-05-26   77
# 3    South Australia     5223  Australia  Australia  1957-09-17   66
# 4           Victoria     3698  Australia  Australia  1965-11-19   58

# %%
def age_group(age):
    if age <= 19:
        return "Teenager"
    elif age >= 20 and age<= 35:
        return "Adult"
    elif age >= 36 and age<= 60:
        return "Middle-Age"
    else:
        return "Senior"

customers_df["AgeGroup"] = customers_df["Age"].apply(age_group)

# %%
customers_df.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday  Age  \
# 0    South Australia     5523  Australia  Australia  1939-07-03   85
# 1  Western Australia     6522  Australia  Australia  1979-09-27   44
# 2           Victoria     3380  Australia  Australia  1947-05-26   77
# 3    South Australia     5223  Australia  Australia  1957-09-17   66
# 4           Victoria     3698  Australia  Australia  1965-11-19   58
#
#      AgeGroup
# 0      Senior
# 1  Middle-Age
# 2      Senior
# 3      Senior
# 4  Middle-Age

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
#  10  Age          15266 non-null  int64
#  11  AgeGroup     15266 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 1.4+ MB

# %%
#age_group=customers_df["AgeGroup"].value_counts()

# %%
#piechart based on agegroup

# %%
# plt.figure(figsize=(17,5))
# plt.pie(age_group,labels=customers_df["Country"],autopct="%1.2f%%")
# plt.title("age_group")
# plt.show()

# %%
customers_df["Country"].value_counts()
# Out:
# Country
# United States     6828
# United Kingdom    1944
# Canada            1553
# Germany           1473
# Australia         1420
# Netherlands        733
# France             670
# Italy              645
# Name: count, dtype: int64

# %%
data_group=customers_df[["AgeGroup","Country","Age"]].groupby(["Country","AgeGroup"]).count()

# %%
data_group
# Out:
#                             Age
# Country        AgeGroup
# Australia      Adult        265
#                Middle-Age   550
#                Senior       605
# Canada         Adult        310
#                Middle-Age   576
#                Senior       667
# France         Adult        127
#                Middle-Age   238
#                Senior       305
# Germany        Adult        278
#                Middle-Age   577
#                Senior       618
# Italy          Adult        135
#                Middle-Age   246
#                Senior       264
# Netherlands    Adult        142
#                Middle-Age   272
#                Senior       319
# United Kingdom Adult        416
#                Middle-Age   699
#                Senior       829
# United States  Adult       1401
#                Middle-Age  2535
#                Senior      2892

# %%
plt.figure(figsize=(18,7))
sns.set_style("darkgrid")
sns.barplot(data=data_group,x="Country",y="Age",hue="AgeGroup")
plt.ylabel("Age Count")
plt.xlabel("Country-->AgeGroup")
plt.show()

# %% [markdown]
# # EXCHANGE RATE

# %%
exchange_df=pd.read_csv("C:\\Users\\admin\\python\\Exchange_Rates.csv")

# %%
exchange_df.head()
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
exchange_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
#renaming the column

# %%
exchange_df.rename(columns={"Currency":"CurrencyCode"},inplace=True)

# %%
exchange_df.head()
# Out:
#        Date CurrencyCode  Exchange
# 0  1/1/2015          USD    1.0000
# 1  1/1/2015          CAD    1.1583
# 2  1/1/2015          AUD    1.2214
# 3  1/1/2015          EUR    0.8237
# 4  1/1/2015          GBP    0.6415

# %%
#data conversion

# %%
exchange_df["Date"]=pd.to_datetime(exchange_df["Date"], format="%m/%d/%Y", errors='coerce').dt.date

# %%
exchange_df.head()
# Out:
#          Date CurrencyCode  Exchange
# 0  2015-01-01          USD    1.0000
# 1  2015-01-01          CAD    1.1583
# 2  2015-01-01          AUD    1.2214
# 3  2015-01-01          EUR    0.8237
# 4  2015-01-01          GBP    0.6415

# %%
exchange_df["Exchange"] =exchange_df["Exchange"].round(2)

# %%
exchange_df.head()
# Out:
#          Date CurrencyCode  Exchange
# 0  2015-01-01          USD      1.00
# 1  2015-01-01          CAD      1.16
# 2  2015-01-01          AUD      1.22
# 3  2015-01-01          EUR      0.82
# 4  2015-01-01          GBP      0.64

# %%
#checking missing values
exchange_df.isnull().sum()
# Out:
# Date            0
# CurrencyCode    0
# Exchange        0
# dtype: int64

# %%
#barchart based on conversion rate

plt.figure(figsize=(18,5))
sns.barplot(data=exchange_df,x="CurrencyCode",y="Exchange",palette='ocean')
plt.ylabel("Conversion Rate")
plt.title("Barchart based on conversion rate")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4312\3965517948.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=exchange_df,x="CurrencyCode",y="Exchange",palette='ocean')

# %% [markdown]
# # PRODUCTS

# %%
products_df=pd.read_csv("C:\\Users\\admin\\python\\Products.csv")

# %%
products_df.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
#checking for missing values

products_df.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
#data conversion

products_df["Unit Cost USD"] = products_df["Unit Cost USD"].str.replace("$","").str.replace(",","")

# %%
products_df["Unit Cost USD"] =products_df["Unit Cost USD"].astype(float)

# %%
products_df["Unit Price USD"] = products_df["Unit Price USD"].str.replace("$","").str.replace(",","")
products_df["Unit Price USD"] =products_df["Unit Price USD"].astype(float)

# %%
products_df.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
#product_details=products_df[["Product Name","Unit Price USD","Brand","Color"]].groupby(["Product Name"]).sum().reset_index()

# %%
category=products_df[["Category","CategoryKey"]]

# %%
category_details_1=category.drop_duplicates().reset_index()

# %%
category_details_1
# Out:
#    index                       Category  CategoryKey
# 0      0                          Audio            1
# 1    115                   TV and Video            2
# 2    337                      Computers            3
# 3    943         Cameras and camcorders            4
# 4   1315                    Cell phones            5
# 5   1570  Music, Movies and Audio Books            6
# 6   1660                 Games and Toys            7
# 7   1826                Home Appliances            8

# %%
category_details_1.drop(["index"],axis=1,inplace=True)

# %%
category_details_1
# Out:
#                         Category  CategoryKey
# 0                          Audio            1
# 1                   TV and Video            2
# 2                      Computers            3
# 3         Cameras and camcorders            4
# 4                    Cell phones            5
# 5  Music, Movies and Audio Books            6
# 6                 Games and Toys            7
# 7                Home Appliances            8

# %%
category_details =products_df.groupby("Category").size().reset_index(name="Category_Count")

# %%
category_details
# Out:
#                         Category  Category_Count
# 0                          Audio             115
# 1         Cameras and camcorders             372
# 2                    Cell phones             285
# 3                      Computers             606
# 4                 Games and Toys             166
# 5                Home Appliances             661
# 6  Music, Movies and Audio Books              90
# 7                   TV and Video             222

# %%
merged_category_details= pd.merge(category_details_1,category_details,on="Category",how="inner")

# %%
merged_category_details
# Out:
#                         Category  CategoryKey  Category_Count
# 0                          Audio            1             115
# 1                   TV and Video            2             222
# 2                      Computers            3             606
# 3         Cameras and camcorders            4             372
# 4                    Cell phones            5             285
# 5  Music, Movies and Audio Books            6              90
# 6                 Games and Toys            7             166
# 7                Home Appliances            8             661

# %%
#dount plot for category items

# %%
plt.figure(figsize=(20,5))
sns.set_style("whitegrid")
plt.pie(category_details["Category_Count"],labels=category_details["Category"],autopct="%1.2f%%",colors=sns.color_palette("pink", len(category_details)))
circle=plt.Circle((0,0),0.40,fc="white")
donut=plt.gcf()
donut.gca().add_artist(circle)
plt.show()

# %%
#products_df["CategoryKey"].value_counts()

# %%
#category_sub=products_df[["SubcategoryKey","Subcategory","CategoryKey"]]

# %%
#category_sub

# %%
#sub_category=category_sub.drop_duplicates().reset_index()

# %%
#sub_category

# %%
sub_categories = products_df.groupby(["SubcategoryKey","Subcategory","CategoryKey"]).size().reset_index(name="Subcategory_Count")

# %%
sub_categories
# Out:
#     SubcategoryKey                       Subcategory  CategoryKey  \
# 0              101                           MP4&MP3            1
# 1              104                     Recording Pen            1
# 2              106              Bluetooth Headphones            1
# 3              201                       Televisions            2
# 4              202                         VCD & DVD            2
# 5              203               Home Theater System            2
# 6              205                         Car Video            2
# 7              301                           Laptops            3
# 8              303                          Desktops            3
# 9              304                          Monitors            3
# 10             305              Projectors & Screens            3
# 11             306          Printers, Scanners & Fax            3
# 12             308             Computers Accessories            3
# 13             401                   Digital Cameras            4
# 14             402               Digital SLR Cameras            4
# 15             405                        Camcorders            4
# 16             406  Cameras & Camcorders Accessories            4
# 17             501              Home & Office Phones            5
# 18             503               Touch Screen Phones            5
# 19             504               Smart phones & PDAs            5
# 20             505           Cell phones Accessories            5
# 21             602                         Movie DVD            6
# 22             701                       Boxed Games            7
# 23             702                    Download Games            7
# 24             801                  Washers & Dryers            8
# 25             802                     Refrigerators            8
# 26             803                        Microwaves            8
# 27             804                     Water Heaters            8
# 28             805                   Coffee Machines            8
# 29             806                             Lamps            8
# 30             807                  Air Conditioners            8
# 31             808                              Fans            8
#
#     Subcategory_Count
# 0                  45
# 1                  20
# 2                  50
# 3                  50
# 4                  26
# 5                 100
# 6                  46
# 7                  78
# 8                  45
# 9                  78
# 10                103
# 11                101
# 12                201
# 13                100
# 14                100
# 15                103
# 16                 69
# 17                 92
# 18                 62
# 19                101
# 20                 30
# 21                 90
# 22                 46
# 23                120
# 24                 70
# 25                 86
# 26                102
# 27                 31
# 28                 74
# 29                158
# 30                 62
# 31                 78

# %%
#barplot for sub_category items

plt.figure(figsize=(15,8))
sns.set_style("whitegrid")
plt.xticks(rotation=90)
pal = sns.color_palette(palette='autumn', n_colors=len(sub_categories))
norm = sub_categories['Subcategory_Count'] / sub_categories['Subcategory_Count'].max()
rank = norm.argsort().argsort()
sns.barplot(data=sub_categories,x="Subcategory",y="Subcategory_Count",palette=np.array(pal)[rank])
plt.xlabel("Products")
plt.ylabel("Items Count")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13096\2488069679.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sub_categories,x="Subcategory",y="Subcategory_Count",palette=np.array(pal)[rank])
# C:\Users\admin\AppData\Local\Temp\ipykernel_13096\2488069679.py:9: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(data=sub_categories,x="Subcategory",y="Subcategory_Count",palette=np.array(pal)[rank])

# %%
products =pd.merge(merged_category_details,sub_categories,on="CategoryKey",how="inner")

# %%
#products.drop("Count",axis=1,inplace=True)

# %%
products
# Out:
#                          Category  CategoryKey  Category_Count  \
# 0                           Audio            1             115
# 1                           Audio            1             115
# 2                           Audio            1             115
# 3                    TV and Video            2             222
# 4                    TV and Video            2             222
# 5                    TV and Video            2             222
# 6                    TV and Video            2             222
# 7                       Computers            3             606
# 8                       Computers            3             606
# 9                       Computers            3             606
# 10                      Computers            3             606
# 11                      Computers            3             606
# 12                      Computers            3             606
# 13         Cameras and camcorders            4             372
# 14         Cameras and camcorders            4             372
# 15         Cameras and camcorders            4             372
# 16         Cameras and camcorders            4             372
# 17                    Cell phones            5             285
# 18                    Cell phones            5             285
# 19                    Cell phones            5             285
# 20                    Cell phones            5             285
# 21  Music, Movies and Audio Books            6              90
# 22                 Games and Toys            7             166
# 23                 Games and Toys            7             166
# 24                Home Appliances            8             661
# 25                Home Appliances            8             661
# 26                Home Appliances            8             661
# 27                Home Appliances            8             661
# 28                Home Appliances            8             661
# 29                Home Appliances            8             661
# 30                Home Appliances            8             661
# 31                Home Appliances            8             661
#
#     SubcategoryKey                       Subcategory  Subcategory_Count
# 0              101                           MP4&MP3                 45
# 1              104                     Recording Pen                 20
# 2              106              Bluetooth Headphones                 50
# 3              201                       Televisions                 50
# 4              202                         VCD & DVD                 26
# 5              203               Home Theater System                100
# 6              205                         Car Video                 46
# 7              301                           Laptops                 78
# 8              303                          Desktops                 45
# 9              304                          Monitors                 78
# 10             305              Projectors & Screens                103
# 11             306          Printers, Scanners & Fax                101
# 12             308             Computers Accessories                201
# 13             401                   Digital Cameras                100
# 14             402               Digital SLR Cameras                100
# 15             405                        Camcorders                103
# 16             406  Cameras & Camcorders Accessories                 69
# 17             501              Home & Office Phones                 92
# 18             503               Touch Screen Phones                 62
# 19             504               Smart phones & PDAs                101
# 20             505           Cell phones Accessories                 30
# 21             602                         Movie DVD                 90
# 22             701                       Boxed Games                 46
# 23             702                    Download Games                120
# 24             801                  Washers & Dryers                 70
# 25             802                     Refrigerators                 86
# 26             803                        Microwaves                102
# 27             804                     Water Heaters                 31
# 28             805                   Coffee Machines                 74
# 29             806                             Lamps                158
# 30             807                  Air Conditioners                 62
# 31             808                              Fans                 78

# %%
pd.set_option('display.max_colwidth', None)
product_categories=products[["Category","Subcategory"]].groupby("Category").agg(list).reset_index()

# %%
product_categories
# Out:
#                         Category  \
# 0                          Audio
# 1         Cameras and camcorders
# 2                    Cell phones
# 3                      Computers
# 4                 Games and Toys
# 5                Home Appliances
# 6  Music, Movies and Audio Books
# 7                   TV and Video
#
#                                                                                                     Subcategory
# 0                                                                [MP4&MP3, Recording Pen, Bluetooth Headphones]
# 1                          [Digital Cameras, Digital SLR Cameras, Camcorders, Cameras & Camcorders Accessories]
# 2                     [Home & Office Phones, Touch Screen Phones, Smart phones & PDAs, Cell phones Accessories]
# 3          [Laptops, Desktops, Monitors, Projectors & Screens, Printers, Scanners & Fax, Computers Accessories]
# 4                                                                                 [Boxed Games, Download Games]
# 5  [Washers & Dryers, Refrigerators, Microwaves, Water Heaters, Coffee Machines, Lamps, Air Conditioners, Fans]
# 6                                                                                                   [Movie DVD]
# 7                                                      [Televisions, VCD & DVD, Home Theater System, Car Video]

# %%
#rearranging the columns
products = pd.DataFrame(products)
reordered=["Category","Category_Count","CategoryKey","Subcategory","Subcategory_Count","SubcategoryKey" ]
df_products=products[reordered]

# %%
df_products
# Out:
#                          Category  Category_Count  CategoryKey  \
# 0                           Audio             115            1
# 1                           Audio             115            1
# 2                           Audio             115            1
# 3                    TV and Video             222            2
# 4                    TV and Video             222            2
# 5                    TV and Video             222            2
# 6                    TV and Video             222            2
# 7                       Computers             606            3
# 8                       Computers             606            3
# 9                       Computers             606            3
# 10                      Computers             606            3
# 11                      Computers             606            3
# 12                      Computers             606            3
# 13         Cameras and camcorders             372            4
# 14         Cameras and camcorders             372            4
# 15         Cameras and camcorders             372            4
# 16         Cameras and camcorders             372            4
# 17                    Cell phones             285            5
# 18                    Cell phones             285            5
# 19                    Cell phones             285            5
# 20                    Cell phones             285            5
# 21  Music, Movies and Audio Books              90            6
# 22                 Games and Toys             166            7
# 23                 Games and Toys             166            7
# 24                Home Appliances             661            8
# 25                Home Appliances             661            8
# 26                Home Appliances             661            8
# 27                Home Appliances             661            8
# 28                Home Appliances             661            8
# 29                Home Appliances             661            8
# 30                Home Appliances             661            8
# 31                Home Appliances             661            8
#
#                          Subcategory  Subcategory_Count  SubcategoryKey
# 0                            MP4&MP3                 45             101
# 1                      Recording Pen                 20             104
# 2               Bluetooth Headphones                 50             106
# 3                        Televisions                 50             201
# 4                          VCD & DVD                 26             202
# 5                Home Theater System                100             203
# 6                          Car Video                 46             205
# 7                            Laptops                 78             301
# 8                           Desktops                 45             303
# 9                           Monitors                 78             304
# 10              Projectors & Screens                103             305
# 11          Printers, Scanners & Fax                101             306
# 12             Computers Accessories                201             308
# 13                   Digital Cameras                100             401
# 14               Digital SLR Cameras                100             402
# 15                        Camcorders                103             405
# 16  Cameras & Camcorders Accessories                 69             406
# 17              Home & Office Phones                 92             501
# 18               Touch Screen Phones                 62             503
# 19               Smart phones & PDAs                101             504
# 20           Cell phones Accessories                 30             505
# 21                         Movie DVD                 90             602
# 22                       Boxed Games                 46             701
# 23                    Download Games                120             702
# 24                  Washers & Dryers                 70             801
# 25                     Refrigerators                 86             802
# 26                        Microwaves                102             803
# 27                     Water Heaters                 31             804
# 28                   Coffee Machines                 74             805
# 29                             Lamps                158             806
# 30                  Air Conditioners                 62             807
# 31                              Fans                 78             808

# %%
category=df_products.groupby(["Category","Subcategory","Subcategory_Count"]).count()

# %%
category.drop(["Category_Count","CategoryKey","SubcategoryKey"],axis=1,inplace=True)

# %%
category
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Audio, Bluetooth Headphones, 50), (Audio, MP4&MP3, 45), (Audio, Recording Pen, 20), (Cameras and camcorders, Camcorders, 103), (Cameras and camcorders, Cameras & Camcorders Accessories, 69), (Cameras and camcorders, Digital Cameras, 100), (Cameras and camcorders, Digital SLR Cameras, 100), (Cell phones, Cell phones Accessories, 30), (Cell phones, Home & Office Phones, 92), (Cell phones, Smart phones & PDAs, 101), (Cell phones, Touch Screen Phones, 62), (Computers, Computers Accessories, 201), (Computers, Desktops, 45), (Computers, Laptops, 78), (Computers, Monitors, 78), (Computers, Printers, Scanners & Fax, 101), (Computers, Projectors & Screens, 103), (Games and Toys, Boxed Games, 46), (Games and Toys, Download Games, 120), (Home Appliances, Air Conditioners, 62), (Home Appliances, Coffee Machines, 74), (Home Appliances, Fans, 78), (Home Appliances, Lamps, 158), (Home Appliances, Microwaves, 102), (Home Appliances, Refrigerators, 86), (Home Appliances, Washers & Dryers, 70), (Home Appliances, Water Heaters, 31), (Music, Movies and Audio Books, Movie DVD, 90), (TV and Video, Car Video, 46), (TV and Video, Home Theater System, 100), (TV and Video, Televisions, 50), (TV and Video, VCD & DVD, 26)]

# %%
#barplot

# %%
plt.figure(figsize=(17,7))
sns.set_style("whitegrid")
sns.barplot(data=category,x="Category",y="Subcategory_Count",hue="Subcategory")
plt.ylabel("Sub category count")
plt.xlabel("Category-->Subcategory")
plt.show()

# %%
products_df.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
df= products_df.head(100)
plt.figure(figsize=(20,6))
sns.lineplot(data=df,x=df.index,y="Unit Cost USD",marker="o",label="Item purchase price by company")
sns.lineplot(data=df,x=df.index,y="Unit Price USD",marker="o",label="Item selling price to customers")
plt.xlabel("Index")
plt.title("price comparison")
plt.show()

# %%
#products_df[["Brand"]].drop_duplicates().reset_index()

# %%
plt.figure(figsize=(45,10))
plt.subplot(1,2,1)
sns.countplot(data=products_df,x=products_df["Brand"],hue="Brand")
plt.xlabel("Brand")
plt.ylabel("product counts")
plt.title("Brand")
plt.show()

# %% [markdown]
# # SALES

# %%
sales_df = pd.read_csv("C:\\Users\\admin\\python\\Sales.csv")

# %%
sales_df.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
sales_df["Order Date"] = pd.to_datetime(sales_df["Order Date"],format= "%m/%d/%Y", errors="coerce").dt.date

# %%
sales_df["Delivery Date"] = pd.to_datetime(sales_df["Delivery Date"],format= "%m/%d/%Y", errors="coerce").dt.date

# %%
sales_df.isnull().mean()*100
# Out:
# Order Number      0.000000
# Line Item         0.000000
# Order Date        0.000000
# Delivery Date    79.064627
# CustomerKey       0.000000
# StoreKey          0.000000
# ProductKey        0.000000
# Quantity          0.000000
# Currency Code     0.000000
# dtype: float64

# %%
sales_df["Delivery Date"] = sales_df["Delivery Date"].fillna(sales_df["Order Date"]+ pd.Timedelta(days=7))

# %%
sales_df.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
sales_df.head()
# Out:
#    Order Number  Line Item  Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1  2016-01-01    2016-01-08       265598        10
# 1        366001          1  2016-01-01    2016-01-13      1269051         0
# 2        366001          2  2016-01-01    2016-01-13      1269051         0
# 3        366002          1  2016-01-01    2016-01-12       266019         0
# 4        366002          2  2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
sales_df[["CustomerKey","StoreKey"]].drop_duplicates().count().reset_index(name="Count")
# Out:
#          index  Count
# 0  CustomerKey  22457
# 1     StoreKey  22457

# %%
order_frequency=sales_df.groupby(['StoreKey', 'CustomerKey'])['Order Number'].nunique().reset_index()
maximum_order=sales_df.groupby(['StoreKey', 'CustomerKey'])['Quantity'].sum().reset_index()

# %%
merged_value=pd.merge(order_frequency,maximum_order,on=["CustomerKey","StoreKey"])

# %%
total_sales=merged_value.sort_values(['StoreKey', 'Quantity'], ascending=[True,False])

# %%
total_sales.head()
# Out:
#       StoreKey  CustomerKey  Order Number  Quantity
# 4057         0      1920128             6        65
# 3256         0      1598675             3        62
# 818          0       461982             3        53
# 2747         0      1414525             6        51
# 2917         0      1473522             3        49

# %%
total_sales_df=total_sales.head(10000)

# %%
plt.figure(figsize=(7,6))
sns.scatterplot(data=total_sales_df,x="StoreKey",y="Quantity")
plt.title("total sale")
plt.show()

# %% [markdown]
# # STORES

# %%
stores_df=pd.read_csv("C:\\Users\\admin\\python\\Stores.csv")

# %%
stores_df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
stores_df["Open Date"] = pd.to_datetime(stores_df["Open Date"], format="%m/%d/%Y", errors='coerce').dt.date

# %%
stores_df.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
#sq_mts_mean=stores_df["Square Meters"].mean()

# %%
#stores_df["Square Meters"].fillna(sq_mts_mean,inplace=True)

# %%
stores_df = stores_df.replace({np.nan: 0})

# %%
stores_df.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
stores_df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#      Open Date
# 0   2008-01-01
# 1   2008-01-12
# 2   2012-01-07
# 3   2010-01-01
# 4   2015-12-09
# ..         ...
# 62  2008-03-06
# 63  2010-01-01
# 64  2012-01-01
# 65  2014-01-01
# 66  2010-01-01
#
# [67 rows x 5 columns]

# %%
#barplot

plt.figure(figsize=(20,7))
sns.scatterplot(data=stores_df,x="Open Date",y="Country")
plt.title("Realtionship between country and store open")
plt.show()

# %%
stores_df.index
# Out:
# RangeIndex(start=0, stop=67, step=1)

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=stores_df,x="State",y="Square Meters",marker="o")
plt.xticks(rotation=90)
plt.show()

# %%
store_group=stores_df[["Country","State"]].groupby(["Country"]).count()

# %%
store_group
# Out:
#                 State
# Country
# Australia           6
# Canada              5
# France              7
# Germany             9
# Italy               3
# Netherlands         5
# Online              1
# United Kingdom      7
# United States      24

# %% [markdown]
# # SQL DATABASE

# %%
conn=mysql.connector.connect(
    host="localhost", 
    user="root", 
    password="root",)
    
my_cursor = conn.cursor()

# %%
my_cursor.execute("CREATE DATABASE IF NOT EXISTS sales_records")

# %%
conn.database = 'sales_records'

# %%
#create table for customers

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS customer_records(
                  CustomerKey INT,
                  Gender VARCHAR(255),
                  Name VARCHAR(255),
                  City VARCHAR(255),
                  State_Code VARCHAR(255),
                  State VARCHAR(255),
                  Zip_Code VARCHAR(255),
                  Country VARCHAR(255),
                  Continent VARCHAR(255),
                  Birthday VARCHAR(255),
                  Age INT,
                  AgeGroup VARCHAR(255)
                  )''')
print("created successful")
# Out:
# created successful

# %%
# insert values into customers

# %%
insert_values='''INSERT INTO customer_records(
                  CustomerKey,
                  Gender,
                  Name,
                  City,
                  State_Code,
                  State,
                  Zip_Code,
                  Country,
                  Continent,
                  Birthday,
                  Age,
                  AgeGroup)
                  VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

# %%
for index, row in customers_df.iterrows():
    my_cursor.execute(insert_values, (
            row['CustomerKey'],
            row['Gender'],
            row['Name'],
            row['City'],
            row['State Code'],
            row['State'],
            row['Zip Code'],
            row['Country'],
            row['Continent'],
            row['Birthday'],
            row['Age'],
            row['AgeGroup']
        ))
    
conn.commit()

# %%
#create table for exchange

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS exchange_records(
                  Date VARCHAR(255),
                  CurrencyCode VARCHAR(255),
                  Exchange FLOAT
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# insert values into exchange

# %%
insert_values ='''INSERT INTO exchange_records(
                  Date,
                 CurrencyCode,
                  Exchange)
                  VALUES (%s, %s, %s)'''

# %%
for index,row in exchange_df.iterrows():
    my_cursor.execute(insert_values,((row['Date'],
                           row['CurrencyCode'],
                           row['Exchange'],
                           ))
                    )
conn.commit()
print("successfully")
# Out:
# successfully

# %%
# create table product

# %%
 
my_cursor.execute('''CREATE TABLE IF NOT EXISTS product_records(
                  ProductKey INT,
                  Product_Name VARCHAR(255),
                  Brand VARCHAR(255),
                  Color VARCHAR(255),
                  Unit_Cost_USD FLOAT,
                  Unit_Price_USD FLOAT,
                  SubcategoryKey INT,
                  Subcategory VARCHAR(255),
                  CategoryKey INT,
                  Category VARCHAR(255)
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
#insert values into Products

# %%
insert_values ='''INSERT INTO product_records(
                  ProductKey,
                  Product_Name,
                  Brand,
                  Color,
                  Unit_Cost_USD,
                  Unit_Price_USD,
                  SubcategoryKey,
                  Subcategory,
                  CategoryKey,
                  Category)
                  VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

# %%
for index,row in products_df.iterrows():
    my_cursor.execute(insert_values,((row['ProductKey'],
                           row['Product Name'],
                           row['Brand'],
                           row['Color'],
                           row['Unit Cost USD'],
                           row['Unit Price USD'],
                           row['SubcategoryKey'],
                           row['Subcategory'],
                           row['CategoryKey'],
                           row['Category']))
                    )
conn.commit()

# %%
#create table sales

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS sales_records(
                  Order_Number INT,
                  Line_Item INT,
                  Order_Date VARCHAR(255),
                  Delivery_Date VARCHAR(255),
                  CustomerKey INT,
                  StoreKey INT,
                  ProductKey INT,
                  Quantity INT,
                  Currency_Code VARCHAR(255)
                  )''')
print("successfully")
# Out:
# successfully

# %%
#insert values into sales

# %%
insert_values ='''INSERT INTO sales_records(
                  Order_Number,
                  Line_Item,
                  Order_Date,
                  Delivery_Date,
                  CustomerKey,
                  StoreKey,
                  ProductKey,
                  Quantity,
                  Currency_Code)
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s)'''

# %%
for index,row in sales_df.iterrows():
    my_cursor.execute(insert_values,((row['Order Number'],
                           row['Line Item'],
                           row['Order Date'],
                           row['Delivery Date'],           
                           row['CustomerKey'],
                           row['StoreKey'],
                           row['ProductKey'],
                           row['Quantity'],
                           row['Currency Code']))
                    )
conn.commit()
print("successful")
# Out:
# successful

# %%
#create table stores

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS stores_records(
                  StoreKey INT,
                  Country VARCHAR(255),
                  State VARCHAR(255),
                  Square_Meters FLOAT,
                  Open_Date VARCHAR(255)
                  )''')
print("successfully")
# Out:
# successfully

# %%
#insert values into stores

# %%
insert_values ='''INSERT INTO stores_records(
                  StoreKey,
                  Country,
                  State,
                  Square_Meters,
                  Open_Date)
                  VALUES (%s, %s, %s, %s, %s)'''

# %%
for index,row in stores_df.iterrows():
    my_cursor.execute(insert_values,((row['StoreKey'],
                           row['Country'],
                           row['State'],
                           row['Square Meters'],
                           row['Open Date']
                           ))
                    )
conn.commit()
print("successful")
# Out:
# successful
